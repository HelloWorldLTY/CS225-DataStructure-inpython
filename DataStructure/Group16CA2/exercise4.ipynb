# %%
#Exercise 1
import copy
import time
class Relation:
    class smallBlock:
        def __init__(self,size):
            self.size = size
            self.tuples = [None] * size
            self.numtuples = 0
        def __getitem__(self,idx):
            return self.tuples[idx]
        def __setitem__(self,idx,t):
            self.tuples[idx] = t
        def getnumtuples(self):
            return self.numtuples
        def insert(self,t):
            for i in range(self.size):
                if self.tuples[i] == None:
                    self.tuples[i] = t
                    self.numtuples += 1
                    return i
            raise IndexError("The block is full.")

        def retrieve(self,idx):
            return self.tuples[idx]
        
        def isfull(self):
            count=0
            for i in range(self.size):
                if self.tuples[i] != None:
                    count +=1
            if count==self.size-1:
                return True
            return False

    class __Placeholder:
        def __init__(self):
            pass
        def __eq__(self,other):
            return False

    def __init__(self,thesize,key):
        self.size=thesize
        self.elements=[None]*self.size
        self.key=key
        #idlist, to help travel.
        self.idxlist=[]
        for i in range(0,self.size//2):
            self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]  

    def insert(self,t):
        if t[0] in self.idxlist:
            raise KeyError('data already exists')
        self.idxlist.append(t[0])
        idx1=t[0]%40
        idx2=t[0]//40
        if self.elements[idx2][0].isfull()== False:
            self.elements[idx2][0][idx1]=t
            self.elements[idx2][0].numtuples+=1

        if self.elements[idx2][0].isfull()== True:
            self.sorting(idx2)
            self.split(self.elements[idx2][1],idx2)
        return self.findpointer(t)
        
    
    def deletion(self,t):
        flag=0
        for i in self.elements:
            if i != None:
                for j in i[0].tuples:
                    if t==j:
                        flag=1
                        num=i[0].tuples.index(j)
                        i[0].tuples[num]=Relation.__Placeholder()
                        i[0].numtuples-=1
                        self.idxlist.remove(j[0])
                        if i[0].numtuples ==i[0].size//2:
                            self.merge(i)
                        return True

                for k in i[1].tuples:
                    if t==k:
                        flag=1
                        num=i[1].tuples.index(k)
                        self.idxlist.remove(k[0])
                        i[1].tuples[num]=Relation.__Placeholder()
                        i[1].numtuples-=1
                        if i[1].numtuples ==i[1].size//2:
                            self.merge(i)
                        return True
        if flag==1:
            return True
            
        if flag==0:
            raise IndexError('No such key')
    
    def keydelete(self,key):
        element=self.find(key)
        self.deletion(element)


    
    def sorting(self,idx2):
        list0=[]
        for i in self.elements[idx2][0].tuples:
            if i!=None and type(i)!=Relation.__Placeholder:
                list0.append(i)
        for i in self.elements[idx2][1].tuples:
            if i!=None and type(i)!=Relation.__Placeholder:
                list0.append(i)

        #Lots of differnet primary keys
        if self.key=='Movie':
            list0.sort(key=lambda x:(x[1],x[2]))

        if self.key=='Person':
            list0.sort(key=lambda x:x[1])
        
        if self.key=='Award':
            list0.sort(key=lambda x:x[1])
        
        if self.key=='Restriction_Category':
            list0.sort(key=lambda x:(x[1],x[2]))
        
        if self.key=='Director':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Writer':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Crew':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Role':
            list0.sort(key=lambda x:(x[2],x[3],x[4]))
        
        if self.key=='Scene':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Restriction':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
        
        if self.key=='Appearance':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
        
        if self.key=='Movie_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Crew_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
        
        if self.key=='Director_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3]))
        
        if self.key=='Writer_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
        
        if self.key=='Actor_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
            
        if self.key=='QMovie_Award':
            list0.sort(key=lambda x:(list(x[2].values())[0][2],list(x[2].values())[1][2],list(x[2].values())[2][2]))
        
        if self.key=='QPerson':
            list0.sort(key=lambda x:list(x[2].values())[0][2])
        
        if self.key=='QRole':
            list0.sort(key=lambda x:(list(x[2].values())[1][2],list(x[2].values())[2][2],list(x[2].values())[3][2]))
        
        if self.key=='QScene':
            list0.sort(key=lambda x:(list(x[2].values())[0][2],list(x[2].values())[1][2],list(x[2].values())[2][2]))
        
        if self.key=='QAppearance':
            list0.sort(key=lambda x:(list(x[2].values())[0][2],list(x[2].values())[1][2],list(x[2].values())[2][2],list(x[2].values())[3][2]))

        if self.key=='QRestriction':
            list0.sort(key=lambda x:(list(x[2].values())[0][2],list(x[2].values())[1][2]))
        
        if self.key=='RActor_Award':
            list0.sort(key=lambda x:(x[1],x[2],x[3],x[4]))
            



        self.elements[idx2][0]=Relation.smallBlock(40)
        self.elements[idx2][1]=Relation.smallBlock(40)
        for j in list0:
            self.elements[idx2][1].insert(j)
        
    
    def split(self,elements,idx):
        for i in range(self.size//2,self.size):
            if self.elements[i]==None:
                self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]
                for j in range(self.elements[i][0].size//2,self.elements[i][0].size):
                    self.elements[i][0].insert(elements[j])
                    self.elements[idx][1][j]=None
                    self.elements[idx][1].numtuples-=1
                return i 
                    
    def merge(self,tuplea):
        list1=[]
        for i in tuplea[0].tuples:
            if i!= None:
                list1.append(i)
        for i in tuplea[1].tuples:
            if i!= None:
                list1.append(i)
        for i in range(0,self.size):
            if self.elements[i]==tuplea:
                if i==0:
                    for k in list1:
                        self.elements[1][0].insert(k)
                    self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]
                    return
                if i==self.size-1:
                    for k in list1:
                        self.elements[self.size-1][0].insert(k)
                    self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]
                    return
                if self.elements[i-1][1].numtuples>=self.elements[i+1][1].numtuples:
                    for k in list1:
                        self.elements[i+1][0].insert(k)
                    self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]
                    return
                if self.elements[i-1][1].numtuples < self.elements[i+1][1].numtuples:
                    for k in list1:
                        self.elements[i-1][0].insert(k)
                    self.elements[i]=[Relation.smallBlock(40),Relation.smallBlock(40)]
                    return

    #This function is same as find/ another kind of retireval.
    def find(self,num):
        #Linear search
        for i in self.elements:
            if i != None:
                for j in i[0].tuples:
                    if j!=None and type(j)!=Relation.__Placeholder and num == j[0]:
                        return j
                couplelist=[]
                for j in i[1].tuples:
                    if j!= None and type(j)!=Relation.__Placeholder:
                        couplelist.append(j)
                if couplelist ==[]:
                    continue
                couplelist.sort(key=lambda x:x[0])
                left=0
                right=len(couplelist)
                #binary search
                while left<=right:
                    mid=(left+right)//2
                    if num<couplelist[mid-1][0]:
                        right=mid-1
                    elif num>couplelist[mid-1][0]:
                        left=mid+1
                    else:
                        return couplelist[mid-1]
        return -1
    
    def retrievedirectly(self,pointer):
        blocknumber = pointer[0]
        idx = pointer[1]
        blocktype=pointer[2]
        return self.elements[blocknumber][blocktype][idx]
    
    def findpointer(self,t):
        for i in range(len(self.elements)):
            if self.elements[i] != None:
                for j in range(self.elements[i][0].size):
                    if self.elements[i][0][j]==t:
                        return (i,j,0)
                for j in range(self.elements[i][1].size):
                    if self.elements[i][1][j]==t:
                        return (i,j,1)

# %%
import copy
from itertools import combinations
import time
#This part is for Graph query.
#In this part we use Graph to help us finish the tasks.
# Original Definition of Graph Class
class Graph:
    def __init__(self,edges=[]):
        self.vertexList = VertexList(edges)
        for e in edges:
            self.addEdge(e)
            self.addEdge((e[1],e[0]))
    def addEdge(self,edge):
        vertex = self.vertexList.locate(edge[0])
        edgelist = vertex.edges
        if edgelist != None:
            edgelist.add(edge[1])
        else:
            edgelist = EdgeList(edge[1])
        vertex.setEdges(edgelist)
    def __iter__(self):
        vertices = self.vertexList
        for v in vertices:
            x = vertices.locate(v)
            y = x.edges
            if y != None:
                for z in y:
                    yield (v,z)
    def insertVertex(self,item):
        if not (item in self.vertexList):
            self.vertexList.append(item)
    def deleteVertex(self,item):
        return self.vertexList.remove(item)
    def insertEdge(self,edge):
        self.vertexList.addVertex(edge)
        self.addEdge(edge)
        self.addEdge((edge[1],edge[0]))
    def deleteEdge(self,edge):
        self.__deleteEdge(edge)
        self.__deleteEdge((edge[1],edge[0]))
    def __deleteEdge(self,edge):
        if not (edge[0] in self.vertexList):
            print("There is no edge", edge)
            return False
        vertexlocation = self.vertexList.locate(edge[0])
        edgelist = vertexlocation.getEdges()
        if edgelist == None:
            print("There is no edge", edge)
            return False
        res = edgelist.remove(edge[1])
        if res == False:
            print("There is no edge", edge)
        return res
    def outgoingEdges(self,item):
        vertex = self.vertexList.locate(item)
        if vertex == None:
            print("There is no vertex", item)
            return []
        edgelist = vertex.getEdges()
        if edgelist == None:
            return []
        res = []
        for v in edgelist:
            res.append((item,v))
        return res
            # yield (item,v) # If we replace the above two lines with this line, then this methods works as an iterator.
    def bfs(self,vertex):
        if not (vertex in self.vertexList):
            print("There is no vertex", vertex)
            return None
        length = self.vertexList.getlength()
        distance = [None] * length
        parent = [None] * length
        index = self.vertexList.index(vertex)
        distance[index] = 0
        parent[index] = vertex
        currentlayer = Fifo(length)
        currentlayer.pushback(vertex)
        nextlayer = Fifo(length)
        for l in range(length):
            for u in currentlayer:
                print(u)
                loc = self.vertexList.locate(u)
                edgelist = loc.getEdges()
                if edgelist != None:
                    for v in edgelist:
                        idx = self.vertexList.index(v)
                        if parent[idx] == None:
                            nextlayer.pushback(v)
                            distance[idx] = l + 1
                            parent[idx] = u
            currentlayer = nextlayer
            nextlayer = Fifo(length)
        return (distance,parent)

    #DFS traverse using recursion
    def allDFS(self):
        numVertices = self.vertexList.getlength()
        initlist = [None]* numVertices
        self.tree = PyList(initlist,numVertices)
        for i in range(numVertices):
            newgraph = Graph([])
            self.tree[i] = newgraph
        for s in self.vertexList:
            self.mark = [None] * numVertices
            self.dfsPos = 1
            self.dfsNum = [1] * numVertices
            self.finishingTime = 1
            self.finishTime = [1] * numVertices
            idx = self.vertexList.index(s)
            if self.mark[idx] == None:
                self.mark[idx] = s
                self.dfsNum[idx] = self.dfsPos
                self.dfsPos += 1
                self.dfs(s,idx)
    def dfs(self,vertex,index):
        for e in self.outgoingEdges(vertex):
            idx = self.vertexList.index(e[1])
            if self.mark[idx] == None:
                self.tree[index].insertEdge(e)
                self.__traverseTreeEdge(e)
                self.mark[idx] = e[1]
                self.dfs(e[1],index)
        self.backtrack(vertex)
        
    def __traverseTreeEdge(self,e):
        idx = self.vertexList.index(e[1])
        self.dfsNum[idx] = self.dfsPos
        self.dfsPos += 1
    def backtrack(self,vertex):
        idx = self.vertexList.index(vertex)
        self.finishTime[idx] = self.finishingTime
        self.finishingTime += 1
    
# Definition of VertexList Class
class VertexList:
    class  __Vertex:
        def __init__(self,item,next=None,previous=None):
            self.item=item
            self.next=next
            self.previous=previous
            self.edges=None
        def getItem(self):
            return self.item
        def getNext(self):
            return self.next
        def getPrevious(self):
            return self.previous
        def getEdges(self):
            return self.edges
        def setItem(self,item):
            self.item = item
        def setNext(self,next):
            self.next = next
        def setPrevious(self,previous):
            self.previous = previous
        def setEdges(self,edge):
            self.edges = edge
    
    def __init__(self,edges=[]):
        self.dummy = VertexList.__Vertex(None,None,None)
        self.numVertices = 0
        self.dummy.setNext(self.dummy)
        self.dummy.setPrevious(self.dummy)
        for e in edges:
            self.addVertex(e)
    def __iter__(self):
        cursor = self.dummy
        for i in range(self.numVertices):
            cursor = cursor.getNext()
            yield cursor.getItem()
    def append(self,item):
        lastVertex = self.dummy.getPrevious()
        newVertex = VertexList.__Vertex(item,self.dummy,lastVertex)
        lastVertex.setNext(newVertex)
        self.dummy.setPrevious(newVertex)
        self.numVertices += 1
    def __contains__(self,item):
        cursor = self.dummy
        for i in range(self.numVertices):
            cursor = cursor.getNext()
            vertex = cursor.getItem()
            if vertex == item:
                return True
        return False
    def locate(self,vertex):
        cursor = self.dummy
        for i in range(self.numVertices):
            cursor = cursor.getNext()
            item = cursor.getItem()
            if vertex == item:
                return cursor
    def addVertex(self,edge):
        node1 = edge[0]
        node2 = edge[1]
        if not (node1 in self):
            self.append(node1)
        if not (node2 in self):
            self.append(node2)
    def remove(self,item):
        cursor = self.dummy
        location = None
        for i in range(self.numVertices):
            cursor = cursor.getNext()
            vertex = cursor.getItem()
            edgelist = cursor.edges
            if edgelist != None:
                if item in edgelist:
                    print(item, "cannot be deleted, as it appears in an edge.")
                    return False
            if vertex == item:
                location = cursor
        if location == None:
            print(item, "is not a vertex.")
            return False
        nextVertex = location.getNext()
        prevVertex = location.getPrevious()
        prevVertex.setNext(nextVertex)
        nextVertex.setPrevious(prevVertex)
        self.numVertices -= 1
        return True
    def index(self,item):
        cursor = self.dummy
        for i in range(self.numVertices):
            cursor = cursor.getNext()
            if cursor.getItem() == item:
                return i
        return -1
    def getlength(self):
        return self.numVertices

# Definition of EdgeList Class
class EdgeList:
    class __Edge:
        def __init__(self,item,next=None,previous=None):
            self.item=item
            self.next=next
            self.previous=previous
        def getItem(self):
            return self.item
        def getNext(self):
            return self.next
        def getPrevious(self):
            return self.previous
        def setItem(self,item):
            self.item = item
        def setNext(self,next):
            self.next = next
        def setPrevious(self,previous):
            self.previous = previous
    
    def __init__(self,edge):
        self.first = EdgeList.__Edge(edge,None,None)
        self.first.setNext(self.first)
        self.first.setPrevious(self.first)
        self.numEdges = 1
    def add(self,edge):
        lastEdge = self.first.getPrevious()
        newEdge = EdgeList.__Edge(edge,self.first,lastEdge)
        lastEdge.setNext(newEdge)
        self.first.setPrevious(newEdge)
        self.numEdges += 1
    def __iter__(self):
        cursor = self.first
        for i in range(self.numEdges):
            yield cursor.getItem()
            cursor = cursor.getNext()
    def __contains__(self,item):
        cursor = self.first
        for i in range(self.numEdges):
            vertex = cursor.getItem()
            if vertex == item:
                return True
            cursor = cursor.getNext()
        return False
    def remove(self,item):
        cursor = self.first
        for i in range(self.numEdges):
            vertex = cursor.getItem()
            if vertex == item:
                nextVertex = cursor.getNext()
                prevVertex = cursor.getPrevious()
                prevVertex.setNext(nextVertex)
                nextVertex.setPrevious(prevVertex)
                self.numEdges -= 1
                if (cursor == self.first):
                    self.first = nextVertex
                return True
            cursor = cursor.getNext()
        return False
# Definition of PyList class
class PyList:
    def __init__(self,contents=[],size=20):
        self.items = [None] * size
        self.numItems = 0
        self.size = size
        for e in contents:
            self.append(e)
    def __setitem__(self,index,val):
        if index >= 0 and index < self.numItems:
            self.items[index] = val
            return
        raise IndexError("PyList assignment index out of range")
    def __getitem__(self,index):
        if index >= 0 and index < self.numItems:
            return self.items[index]
        raise IndexError("PyList index out of range")
    def append(self,item):
        if self.numItems == self.size:
            self.allocate()
        self.items[self.numItems] = item
        self.numItems += 1
    def allocate(self):
        newlength = 2 * self.size
        newList = [None] * newlength
        for i in range(self.numItems):
            newList[i] = self.items[i]
        self.items = newList
        self.size = newlength
    def insert(self,i,x):
        if self.numItems == self.size:
            self.allocate()
        if i < self.numItems:
            for j in range(self.numItems-1,i,-1):
                self.items[j+1] = self.items[j]
            self.items[i] = x
            self.numItems += 1
        else:
            self.append(x)
    def __add__(self,other):
        result = PyList(size=self.numItems+other.numItems)
        for i in range(self.numItems):
            result.append(self.items[i])
        for i in range(other.numItems):
            result.append(other.items[i])
        return result
    def delete(self,index):
        if self.numItems == self.size / 4:
            self.deallocate()
        if index <= self.numItems:
            for j in range(index,self.numItems-2):
                self.items[j] = self.items[j+1]
            self.numItems -= 1
        else:
            raise IndexError("PyList index out of range")
    def deallocate(self):
        newlength = self.size / 2
        newList = [None] * newlength
        for i in range(self.numItems):
            newList[i] = self.items[i]
        self.items = newList
        self.size = newlength
    def __contains__(self,item):
        for i in range(self.numItems):
            if self.items[i] == item:
                return True
            return False
    def __eq__(self,other):
        if type(other) != type(self):
            return False
        if self.numItems != other.numItems:
            return False
        for i in range(self.numItems):
            if self.items[i] != self.items[i]:
                return False
            return True
    def qsort(self):
        if self.numItems <= 1:
            return self
        pivot = self.items[0]
        list1 = PyList([],self.numItems)
        listp = PyList([],self.numItems)
        list2 = PyList([],self.numItems)
        for i in range(self.numItems):
            if self.items[i] < pivot:
                list1.append(self.items[i])
            else:
                if self.items[i] == pivot:
                    listp.append(self.items[i])
                else:
                    list2.append(self.items[i])
        slist1 = list1.qsort()
        slist2 = list2.qsort()
        outlist = slist1 + listp + slist2
        return outlist
    def radixSort(self,numdigits,digits):
        sortedlist = self
        for i in range(numdigits):
            sortedlist = sortedlist.Ksort(i,digits)
        return sortedlist          
    def Ksort(self,round,digits):
        bucket = PyList([],digits)
        for k in range(digits):
            newlist = PyList([],self.numItems)
            bucket.append(newlist)
        for i in range(self.numItems):
            item = self.items[i]
            item1 = item // (digits ** round) % digits
            bucket[item1].append(item)
        result = bucket[0]
        for k in range(digits-1):
            result = result + bucket[k+1]
        return result

# Definition of FIFO class
class Fifo:
    def __init__(self,size=20):
        self.items = [None] * size
        self.first = 0
        self.last = -1
        self.size = size
        self.length = 0
    def computelength(self):
        if self.last >= self.first:
            self.length = self.last - self.first + 1
        else:
            self.length = self.last - self.first + 1 + self.size
    def isEmpty(self):
        if self.length != 0:
            return False
        return True
    def front(self):
        if self.length != 0:
            return self.items[self.last]
        raise IndexError("Queue is empty")
    def back(self):
        if self.length != 0:
            return self.items[self.first]
        raise IndexError("Queue is empty")
    def pushback(self,item):
        if self.length == self.size:
            self.allocate()
        self.last = (self.last + 1) % self.size
        self.items[self.last] = item
        self.computelength()
    def popfront(self):
        if self.length == self.size / 4:
            self.deallocate()
        if self.last - self.first + 1 != 0:
            frontelement = self.items[self.last]
            self.first = (self.first + 1) % self.size
            self.computelength()
            return frontelement
        raise IndexError("Queue is empty")
    def __iter__(self):
        rlast = self.first + self.length
        for i in range(self.first,rlast):
            yield self.items[i % self.size]
    def allocate(self):
        newlength = 2 * self.size
        newQueue = [None] * newlength
        for i in range(self.size):
            pos = (i + self.first) % self.size
            newQueue[i] = self.items[pos]
        self.items = newQueue
        self.first = 0
        self.last = self.size - 1
        self.size = newlength
        self.computelength()
    def deallocate(self):
        newlength = self.size / 2
        newQueue = [None] * newlength
        length = (self.last - self.first +1) % self.size
        for i in range(length):
            pos = (i + self.first) % self.size
            newQueue[i] = self.items[pos]
        self.items = newQueue
        self.first = 0
        self.last = length - 1
        self.size = newlength
        self.computelength()

# %%
#Data clean part
#database for CA1
database={}
database['i1'] = ('i1','Theatre',{'i2':('i2','cinema','Abaton'),'i3':('i3','address','Grindle Alley')})
database['i4'] = ('i4','Theatre',{'i5':('i5','cinema','Flora'),'i6':('i6','address','Old Village')})
database['i7'] = ('i7','Theatre',{'i8':('i8','cinema','Holi')})
database['i10']= ('i10','Performance',{'i11':('i11','cinema','Flora'),'i12':('i12','title','The Piano'),'i13':('i13','date','May 7')})
database['i14']= ('i14','Performance',{'i15':('i15', 'cinema', 'Holi'), '16':('i16', 'title', 'Manhattan')})
database['i17']= ('i17','Play',{'i18':('i18','title','S10'),'i19':('i19','director','UZI')})
database['i20']= ('i20','Play',{'i21':('i21', 'title', 'The Piano'), 'i22':('i22', 'director', 'Campio')})
database['i23']= ('i23','Play',{'i24':('i24', 'title', 'Manhattan'), 'i25':('i25', 'director', 'Allen')})
database['i30']= ('i30','Nationality',{'i31':('i31', 'director', 'Campio'), 'i32':('i32', 'country', 'USA')})
database['i33']= ('i33','Nationality',{'i34':('i34', 'director', 'Allen'),'i35':('i35', 'country', 'USA')})
database['i36'] = ('i36','Number',{'i37':('i37','numberlist',[1,5,6,4,3,2])})

def database_exchanger(database1,database2):
    for i in database1.idxlist:
        element=database1.find(i)
        database2[i]=element
    return database2
#database for CA2
RMovie_Award=Relation(1000,'QMovie_Award') 
RPerson=Relation(1000,'QPerson')
RRole=Relation(1000,'QRole')
RScene=Relation(1000,'QScene')
RAppearance=Relation(1000,'QAppearance')
RActor_award=Relation(1000,'RActor_award')


#database for CA2
#This part includes the transformation function that changes the tuples of Relation intto our Database.
#Awarded Movie:
Movie_Award={}

RMovie_Award.insert((1,'Movie',{1.1:(1.1,'m','Traffic'),1.2:(1.2,'y',2000),1.3:(1.3,'a','NYFCC Award'),1.4:(1.4,'z',2000),1.5:(1.5,'cg','Best Film'),1.6:(1.6,'r','Won')}))
database_exchanger(RMovie_Award,Movie_Award)

#Actor
Person={}

RPerson.insert((1,'Person',{1.1:(1.1,'id','00000443'),1.2:(1.2,'f','Michael'),1.3:(1.3,'n','Douglas'),1.4:(1.4,'y',1944)}))
RPerson.insert((2,'Person',{2.1:(2.1,'id','00000444'),2.2:(2.2,'f','Benicio'),2.3:(2.3,'n','Del Toro'),2.4:(2.4,'y',1967)}))
RPerson.insert((3,'Person',{3.1:(3.1,'id','00000445'),3.2:(3.2,'f','Catherine'),3.3:(3.3,'n','Zeta-Jones'),3.4:(3.4,'y',1969)}))
RPerson.insert((4,'Person',{4.1:(4.1,'id','00000446'),4.2:(4.2,'f','Stephen'),4.3:(4.3,'n','Bauer'),4.4:(4.4,'y',1956)}))
RPerson.insert((5,'Person',{5.1:(5.1,'id','00000447'),5.2:(5.2,'f','Luis'),5.3:(5.3,'n','Guzman'),5.4:(5.4,'y',1967)}))
RPerson.insert((6,'Person',{6.1:(6.1,'id','00000448'),6.2:(6.2,'f','Amy'),6.3:(6.3,'n','Irving'),6.4:(6.4,'y',1953)}))
RPerson.insert((7,'Person',{7.1:(7.1,'id','00000449'),7.2:(7.2,'f','Erika'),7.3:(7.3,'n','Christensen'),7.4:(7.4,'y',1982)}))
RPerson.insert((8,'Person',{8.1:(8.1,'id','00000450'),8.2:(8.2,'f','Don'),8.3:(8.3,'n','Cheadle'),8.4:(8.4,'y',1964)}))
RPerson.insert((9,'Person',{9.1:(9.1,'id','00000451'),9.2:(9.2,'f','Jacob'),9.3:(9.3,'n','Vargas'),9.4:(9.4,'y',1963)}))
RPerson.insert((10,'Person',{10.1:(10.1,'id','00000452'),10.2:(10.2,'f','Clifton'),10.3:(10.3,'n','Collins'),10.4:(10.4,'y',1971)}))
database_exchanger(RPerson,Person)

#Role
Role={}

RRole.insert((1,'Role',{1.1:(1.1,'id','00000443'),1.2:(1.2,'m','Traffic'),1.3:(1.3,'y',2000),1.4:(1.4,'d','Robert Wakefield')}))
RRole.insert((2,'Role',{2.1:(2.1,'id','00000444'),2.2:(2.2,'m','Traffic'),2.3:(2.3,'y',2000),2.4:(2.4,'d','Javier Rodriguez')}))
RRole.insert((3,'Role',{3.1:(3.1,'id','00000445'),3.2:(3.2,'m','Traffic'),3.3:(3.3,'y',2000),3.4:(3.4,'d','Helena Ayala')}))
RRole.insert((4,'Role',{4.1:(4.1,'id','00000446'),4.2:(4.2,'m','Traffic'),4.3:(4.3,'y',2000),4.4:(4.4,'d','Carlos Ayala')}))
RRole.insert((5,'Role',{5.1:(5.1,'id','00000447'),5.2:(5.2,'m','Traffic'),5.3:(5.3,'y',2000),5.4:(5.4,'d','Ray Castro')}))
RRole.insert((6,'Role',{6.1:(6.1,'id','00000448'),6.2:(6.2,'m','Traffic'),6.3:(6.3,'y',2000),6.4:(6.4,'d','Barbara Wakefield')}))
RRole.insert((7,'Role',{7.1:(7.1,'id','00000449'),7.2:(7.2,'m','Traffic'),7.3:(7.3,'y',2000),7.4:(7.4,'d','Caroline Wakefield')}))
RRole.insert((8,'Role',{8.1:(8.1,'id','00000450'),8.2:(8.2,'m','Traffic'),8.3:(8.3,'y',2000),8.4:(8.4,'d','Montel Gordon')}))
RRole.insert((9,'Role',{9.1:(9.1,'id','00000451'),9.2:(9.2,'m','Traffic'),9.3:(9.3,'y',2000),9.4:(9.4,'d','Manolo Sanchez')}))
RRole.insert((10,'Role',{10.1:(10.1,'id','00000452'),10.2:(10.2,'m','Traffic'),10.3:(10.3,'y',2000),10.4:(10.4,'d','Francisco Flores')}))
database_exchanger(RRole,Role)



#Scene
Scene={}

RScene.insert((1,'Scene',{1.1:(1.1,'m','Traffic'),1.2:(1.2,'y',2000),1.3:(1.3,'s',1),1.4:(1.4,'d','Corruption at Mexican Border')}))
RScene.insert((2,'Scene',{2.1:(2.1,'m','Traffic'),2.2:(2.2,'y',2000),2.3:(2.3,'s',2),2.4:(2.4,'d','A new anti-drug czar')}))
RScene.insert((3,'Scene',{3.1:(3.1,'m','Traffic'),3.2:(3.2,'y',2000),3.3:(3.3,'s',3),3.4:(3.4,'d','Addicted to Drugs')}))
RScene.insert((4,'Scene',{4.1:(4.1,'m','Traffic'),4.2:(4.2,'y',2000),4.3:(4.3,'s',4),4.4:(4.4,'d','Arresting a Baron')}))
RScene.insert((5,'Scene',{5.1:(5.1,'m','Traffic'),5.2:(5.2,'y',2000),5.3:(5.3,'s',5),5.4:(5.4,'d','Temptations')}))
RScene.insert((6,'Scene',{6.1:(6.1,'m','Traffic'),6.2:(6.2,'y',2000),6.3:(6.3,'s',6),6.4:(6.4,'d','Loosing Caroline')}))
RScene.insert((7,'Scene',{7.1:(7.1,'m','Traffic'),7.2:(7.2,'y',2000),7.3:(7.3,'s',7),7.4:(7.4,'d','Taking over the Business')}))
RScene.insert((8,'Scene',{8.1:(8.1,'m','Traffic'),8.2:(8.2,'y',2000),8.3:(8.3,'s',8),8.4:(8.4,'d','Untenable Situation')}))
RScene.insert((9,'Scene',{9.1:(9.1,'m','Traffic'),9.2:(9.2,'y',2000),9.3:(9.3,'s',9),9.4:(9.4,'d','Assassains')}))
RScene.insert((10,'Scene',{10.1:(10.1,'m','Traffic'),10.2:(10.2,'y',2000),10.3:(10.3,'s',10),10.4:(10.4,'d','New Family Values')}))
RScene.insert((11,'Scene',{11.1:(11.1,'m','Traffic'),11.2:(11.2,'y',2000),11.3:(11.3,'s',11),11.4:(11.4,'d','The Fight goes on')}))
database_exchanger(RScene,Scene)


#Appearance
Appearance={}

RAppearance.insert((1,'Appearance',{1.1:(1.1,'m','Traffic'),1.2:(1.2,'y',2000),1.3:(1.3,'d','Javier Rodriguez'),1.4:(1.4,'s',1)}))
RAppearance.insert((2,'Appearance',{2.1:(2.1,'m','Traffic'),2.2:(2.2,'y',2000),2.3:(2.3,'d','Manolo Sanchez'),2.4:(2.4,'s',1)}))
RAppearance.insert((3,'Appearance',{3.1:(3.1,'m','Traffic'),3.2:(3.2,'y',2000),3.3:(3.3,'d','Robert Wakefield'),3.4:(3.4,'s',2)}))
RAppearance.insert((4,'Appearance',{4.1:(4.1,'m','Traffic'),4.2:(4.2,'y',2000),4.3:(4.3,'d','Barbara Wakefield'),4.4:(4.4,'s',2)}))
RAppearance.insert((5,'Appearance',{5.1:(5.1,'m','Traffic'),5.2:(5.2,'y',2000),5.3:(5.3,'d','Caroline Wakefield'),5.4:(5.4,'s',3)}))
RAppearance.insert((6,'Appearance',{6.1:(6.1,'m','Traffic'),6.2:(6.2,'y',2000),6.3:(6.3,'d','Montel Gordon'),6.4:(6.4,'s',4)}))
RAppearance.insert((7,'Appearance',{7.1:(7.1,'m','Traffic'),7.2:(7.2,'y',2000),7.3:(7.3,'d','Ray Castro'),7.4:(7.4,'s',4)}))
RAppearance.insert((8,'Appearance',{8.1:(8.1,'m','Traffic'),8.2:(8.2,'y',2000),8.3:(8.3,'d','Carlos Ayala'),8.4:(8.4,'s',4)}))
RAppearance.insert((9,'Appearance',{9.1:(9.1,'m','Traffic'),9.2:(9.2,'y',2000),9.3:(9.3,'d','Helena Ayala'),9.4:(9.4,'s',4)}))
RAppearance.insert((10,'Appearance',{10.1:(10.1,'m','Traffic'),10.2:(10.2,'y',2000),10.3:(10.3,'d','Manolo Sanchez'),10.4:(10.4,'s',5)}))
RAppearance.insert((11,'Appearance',{11.1:(11.1,'m','Traffic'),11.2:(11.2,'y',2000),11.3:(11.3,'d','Ray Castro'),11.4:(11.4,'s',5)}))
RAppearance.insert((12,'Appearance',{12.1:(12.1,'m','Traffic'),12.2:(12.2,'y',2000),12.3:(12.3,'d','Javier Rodriguez'),12.4:(12.4,'s',5)}))
RAppearance.insert((13,'Appearance',{13.1:(13.1,'m','Traffic'),13.2:(13.2,'y',2000),13.3:(13.3,'d','Montel Gordon'),13.4:(13.4,'s',5)}))

RAppearance.insert((14,'Appearance',{14.1:(14.1,'m','Traffic'),14.2:(14.2,'y',2000),14.3:(14.3,'d','Robert Wakefield'),14.4:(14.4,'s',6)}))
RAppearance.insert((15,'Appearance',{15.1:(15.1,'m','Traffic'),15.2:(15.2,'y',2000),15.3:(15.3,'d','Barbara Wakefield'),15.4:(15.4,'s',6)}))
RAppearance.insert((16,'Appearance',{16.1:(16.1,'m','Traffic'),16.2:(16.2,'y',2000),16.3:(16.3,'d','Caroline Wakefield'),16.4:(16.4,'s',6)}))
RAppearance.insert((17,'Appearance',{17.1:(17.1,'m','Traffic'),17.2:(17.2,'y',2000),17.3:(17.3,'d','Francisco Flores'),17.4:(17.4,'s',6)}))
RAppearance.insert((18,'Appearance',{18.1:(18.1,'m','Traffic'),18.2:(18.2,'y',2000),18.3:(18.3,'d','Montel Gordon'),18.4:(18.4,'s',6)}))

RAppearance.insert((19,'Appearance',{19.1:(19.1,'m','Traffic'),19.2:(19.2,'y',2000),19.3:(19.3,'d','Robert Wakefield'),19.4:(19.4,'s',7)}))
RAppearance.insert((20,'Appearance',{20.1:(20.1,'m','Traffic'),20.2:(20.2,'y',2000),20.3:(20.3,'d','Barbara Wakefield'),20.4:(20.4,'s',7)}))
RAppearance.insert((21,'Appearance',{21.1:(21.1,'m','Traffic'),21.2:(21.2,'y',2000),21.3:(21.3,'d','Caroline Wakefield'),21.4:(21.4,'s',7)}))
RAppearance.insert((22,'Appearance',{22.1:(22.1,'m','Traffic'),22.2:(22.2,'y',2000),22.3:(22.3,'d','Francisco Flores'),22.4:(22.4,'s',7)}))

RAppearance.insert((23,'Appearance',{23.1:(23.1,'m','Traffic'),23.2:(23.2,'y',2000),23.3:(23.3,'d','Javier Rodriguez'),23.4:(23.4,'s',8)}))
RAppearance.insert((24,'Appearance',{24.1:(24.1,'m','Traffic'),24.2:(24.2,'y',2000),24.3:(24.3,'d','Manolo Sanchez'),24.4:(24.4,'s',8)}))
RAppearance.insert((25,'Appearance',{25.1:(25.1,'m','Traffic'),25.2:(25.2,'y',2000),25.3:(25.3,'d','Robert Wakefield'),25.4:(25.4,'s',8)}))
RAppearance.insert((26,'Appearance',{26.1:(26.1,'m','Traffic'),26.2:(26.2,'y',2000),26.3:(26.3,'d','Barbara Wakefield'),26.4:(26.4,'s',8)}))

RAppearance.insert((27,'Appearance',{27.1:(27.1,'m','Traffic'),27.2:(27.2,'y',2000),27.3:(27.3,'d','Francisco Flores'),27.4:(27.4,'s',9)}))
RAppearance.insert((28,'Appearance',{28.1:(28.1,'m','Traffic'),28.2:(28.2,'y',2000),28.3:(28.3,'d','Robert Wakefield'),28.4:(28.4,'s',9)}))
RAppearance.insert((29,'Appearance',{29.1:(29.1,'m','Traffic'),29.2:(29.2,'y',2000),29.3:(29.3,'d','Montel Gordon'),29.4:(29.4,'s',9)}))
RAppearance.insert((30,'Appearance',{30.1:(30.1,'m','Traffic'),30.2:(30.2,'y',2000),30.3:(30.3,'d','Carlos Ayala'),30.4:(30.4,'s',9)}))

RAppearance.insert((31,'Appearance',{31.1:(31.1,'m','Traffic'),31.2:(31.2,'y',2000),31.3:(31.3,'d','Robert Wakefield'),31.4:(31.4,'s',10)}))
RAppearance.insert((32,'Appearance',{32.1:(32.1,'m','Traffic'),32.2:(32.2,'y',2000),32.3:(32.3,'d','Barbara Wakefield'),32.4:(32.4,'s',10)}))
RAppearance.insert((33,'Appearance',{33.1:(33.1,'m','Traffic'),33.2:(33.2,'y',2000),33.3:(33.3,'d','Caroline Wakefield'),33.4:(33.4,'s',10)}))
RAppearance.insert((34,'Appearance',{34.1:(34.1,'m','Traffic'),34.2:(34.2,'y',2000),34.3:(34.3,'d','Carlos Ayala'),34.4:(34.4,'s',10)}))
RAppearance.insert((35,'Appearance',{35.1:(35.1,'m','Traffic'),35.2:(35.2,'y',2000),35.3:(35.3,'d','Montel Gordon'),35.4:(35.4,'s',10)}))
RAppearance.insert((36,'Appearance',{36.1:(36.1,'m','Traffic'),36.2:(36.2,'y',2000),36.3:(36.3,'d','Manolo Sanchez'),36.4:(36.4,'s',10)}))
RAppearance.insert((37,'Appearance',{37.1:(37.1,'m','Traffic'),37.2:(37.2,'y',2000),37.3:(37.3,'d','Francisco Flores'),37.4:(37.4,'s',10)}))

RAppearance.insert((38,'Appearance',{38.1:(38.1,'m','Traffic'),38.2:(38.2,'y',2000),38.3:(38.3,'d','Carlos Ayala'),38.4:(38.4,'s',11)}))
RAppearance.insert((39,'Appearance',{39.1:(39.1,'m','Traffic'),39.2:(39.2,'y',2000),39.3:(39.3,'d','Helena Ayala'),39.4:(39.4,'s',11)}))
RAppearance.insert((40,'Appearance',{40.1:(40.1,'m','Traffic'),40.2:(40.2,'y',2000),40.3:(40.3,'d','Montel Gordon'),40.4:(40.4,'s',11)}))
database_exchanger(RAppearance,Appearance)

#actor award
Actor_award={}

RActor_award.insert((1,'Actor_award',{1.1:(1.1,'m','Traffic'),1.2:(1.2,'y',2000),1.3:(1.3,'d','Javier Rodriguez'),1.4:(1.4,'a','Oscar'),1.5:(1.5,'z',2001),1.6:(1.6,'cg','best actor in a supporting role'),1.7:(1.7,'r','won')}))
RActor_award.insert((2,'Actor_award',{2.1:(2.1,'m','Traffic'),2.2:(2.2,'y',2000),2.3:(2.3,'d','Javier Rodriguez'),2.4:(2.4,'a','Golden Globe Awards'),2.5:(2.5,'z',2001),2.6:(2.6,'cg','best actor in a supporting role'),2.7:(2.7,'r','won')}))
RActor_award.insert((3,'Actor_award',{3.1:(3.1,'m','Traffic'),3.2:(3.2,'y',2000),3.3:(3.3,'d','Javier Rodriguez'),3.4:(3.4,'a','Silver Berlin Bear'),3.5:(3.5,'z',2001),3.6:(3.6,'cg','Best Actor'),3.7:(3.7,'r','won')}))
database_exchanger(RActor_award,Actor_award)
# Out:
# {1: (1,
#   'Actor_award',
#   {1.1: (1.1, 'm', 'Traffic'),
#    1.2: (1.2, 'y', 2000),
#    1.3: (1.3, 'd', 'Javier Rodriguez'),
#    1.4: (1.4, 'a', 'Oscar'),
#    1.5: (1.5, 'z', 2001),
#    1.6: (1.6, 'cg', 'best actor in a supporting role'),
#    1.7: (1.7, 'r', 'won')}),
#  2: (2,
#   'Actor_award',
#   {2.1: (2.1, 'm', 'Traffic'),
#    2.2: (2.2, 'y', 2000),
#    2.3: (2.3, 'd', 'Javier Rodriguez'),
#    2.4: (2.4, 'a', 'Golden Globe Awards'),
#    2.5: (2.5, 'z', 2001),
#    2.6: (2.6, 'cg', 'best actor in a supporting role'),
#    2.7: (2.7, 'r', 'won')}),
#  3: (3,
#   'Actor_award',
#   {3.1: (3.1, 'm', 'Traffic'),
#    3.2: (3.2, 'y', 2000),
#    3.3: (3.3, 'd', 'Javier Rodriguez'),
#    3.4: (3.4, 'a', 'Silver Berlin Bear'),
#    3.5: (3.5, 'z', 2001),
#    3.6: (3.6, 'cg', 'Best Actor'),
#    3.7: (3.7, 'r', 'won')})}

# %%
#Define a stack
#2SAM part
class Stack:
    def __init__(self,size=20):
        self.items = [None] * size
        self.numItems = 0
        self.size = size
        
    def top(self):
        if self.numItems != 0:
            return self.items[self.numItems-1]
        raise IndexError("Stack is empty")
        
    def push(self,item):
        if self.numItems >= self.size:
            self.allocate()
        self.items[self.numItems] = item
        self.numItems += 1
        
    def allocate(self):
        newlength = 2 * self.size
        newStack = [None] * newlength
        for i in range(self.numItems):
            newStack[i] = self.items[i]
        self.items = newStack
        self.size = newlength
        
    def pop(self):
        if self.numItems != 0:
            topelement = self.items[self.numItems-1]
            self.numItems -= 1
            return topelement
        raise IndexError("Stack is empty")
        
    def deallocate(self):
        newlength = self.size //2
        newStack = [None] * newlength
        for i in range(self.numItems):
            newStack[i] = self.items[i]
        self.items = newStack
        self.size = newlength
        
    def isEmpty(self):
        if self.numItems != 0:
            return False
        return True

    def search(self,n):
        for i in range(self.numItems):
            if n == self.items[i]:
                return True
        return False

#Functions mainly used in (i)
#Use this method to find naive associate actors pairs.
#This is normally not the final result, since the definition of associate shows the transitivity.   
def giveassociate(graph):
    scene1=list(Appearance.keys())
    maxscene=scene1[-1]
    scenelist=[i for i in range(1,maxscene+1)]
    result=[None]*(len(scenelist)+1)
    namelist=set()
    for i in scene1:
        res1=list(Appearance[i][2].keys())
        key=Appearance[i][2][res1[3]][2]
        if result[key]==None:
            val=dereferencenew(res1[2],Appearance)
            result[key]=[val]
            namelist.add(val)
        else:
            val=dereferencenew(res1[2],Appearance)
            result[key].append(val)
            namelist.add(val)
    finalresult=[]
    for i in result:
        if i!=None:
            finalresult.append(i)
    result=[]
    for i in finalresult:
        #Give the cimbinations of actors in the same scene.
        result.append(list(combinations(i,2)))
    result=[result[i] for i in range(0,len(result)) if result[i] != []]
    namelist=list(namelist)
    #Since the graph class in the class can only hold 'int' type data.
    #We need to change the strings into 'int' index.
    for i in range(0,len(result)):
        for j in range(0,len(result[i])):
            k1=namelist.index(result[i][j][0])
            k2=namelist.index(result[i][j][1])
            result[i][j]=(k1,k2)
            graph.insertEdge((k1,k2))
    namelist.sort()
    return namelist
    

#Find the total associate occur in this relation.
def findassociate(graph,actor):
    result=set()
    namelist=set()
    associateset=[]
    for i in graph:
        result.add(i)
        namelist.add(i[0])
    
    result=list(result)
    namelist=list(namelist)
    result.sort(key=lambda x:x[0])
    namelist.sort()
    
    #Using definiation to check the associate
    #iterate result until no more change
    for i in result:
        for k in namelist:
            if (i[0],namelist.index(k)) in result and (namelist.index(k),i[1]) not in result:
                if i[1]!=namelist.index(k):
                    result.append((namelist.index(k),i[1]))
            if (i[0],namelist.index(k)) not in result and (namelist.index(k),i[1])  in result:
                if i[0]!=namelist.index(k):
                    result.append((i[0],namelist.index(k)))
            if (i[1],namelist.index(k)) in result and (namelist.index(k),i[0]) not in result:
                if i[0]!=namelist.index(k):
                    result.append((namelist.index(k),i[0]))
            if (i[1],namelist.index(k)) not in result and (namelist.index(k),i[0])  in result:
                if i[1]!=namelist.index(k):
                    result.append((i[1],namelist.index(k)))
                  
    result=list(set(result))
    for i in result:
        if i in result and (i[1],i[0]) in result:
            result.remove((i[1],i[0]))
    result.sort()
    rolename=[]
    for i in result:
        rolename.append((actor[i[0]],actor[i[1]]))
    return rolename

#Function mainly used in (ii)
#This function is used to find the admirer directly.
def getadmirer(graph,role):
    set0=set()
    rolename=findassociate(graph,role)
    database=Actor_award
    for i in database.keys():
        list0=dereferencenew(i,database)
        awardrole=dereferencenew(list0[2],database)
        set0.add(awardrole)
    set0=list(set0)
    admirer=set()
    actorlist=findcommonapp()
    #Use the definition to find the all admirer pairs.
    #iterate admirer.
    for i in set0:
        for j in actorlist:
            if i in j:
                keyward=j[0]
                for k in actorlist:
                    if (k[0]==keyward) and (k[1]!=i):
                        tuplename=((k[1],i))
                        admirer.add(tuplename)
    for i in set0:
        for j in rolename:
            if j not in admirer:
                if (j[0],i) in admirer and (i,j[1]) in admirer:
                    admirer.add(j)
    
    #Give the result.
    admirer=list(admirer)
    admirer.sort()
    RES.push(admirer)



#Functionlist
def dereference(ident):
    for i in database.keys():
        if i != ident:
            for j in database[i][2].keys():
                if ident == j:
                    return database[i][2][j][2]
        else:
            return list(database[i][2].keys())

def findname(ident):
    for i in database.keys():
        if i != ident:
            for j in database[i][2].keys():
                if ident == j:
                    return database[i][2][j][1]
        else:
            return database[i][1]

def nametestbigtitle(name):
    bigtitle=[]
    for i in database.keys():
        if database[i][1] == name[0]:
            bigtitle.append(i)
    if bigtitle != []:
        RES.push(bigtitle)
        return True
    return False

def nametestsmalltitle(name):
    smalltitle=[]
    for i in database.keys():
        for j in database[i][2].keys():
            if database[i][2][j][1] == name[0]:
                smalltitle.append(j)
    if smalltitle != []:
        ENV.push(smalltitle)
        return True
    return False

def valuetest(name):
    valueresult=[]
    for i in database.keys():
        if dereference(i) == name[0]:
            valueresult.append(i)
        else:
            for j in database[i][2].keys():
                if dereference(j) == name[0]:
                    valueresult.append(j)
    if valueresult != []:
        ENV.push(valueresult)
        return True    
    return False


def distinct(result):
    return set(result)
    

def In(a,b):
    for genre in b:
        for name in a:
            if name in database[genre][2].keys():
                return True

    return False
    
def Contains(a,b):
    seta = set(a)
    setb = set(b)
    return seta.issubset(setb)

def Exist(a):
    if a == []:
        return False
    return True

def testmoviename(query):
    if 'Movie' in query[0]:
        return True
    return False

def testsceneame(query):
    if 'scene' in query[0]:
        return True
    return False

def testassociate(query):
    if 'associate' in query[0]:
        return True
    return False

def testadmirer(query):
    if 'admirer' in query[0]:
        return True
    return False

def creategraphcheck(query):
    namerequired=[]
    for i in Movie_Award.keys():
        namerequired.append(dereferencenew(i,Movie_Award))
    for j in namerequired:
        if dereferencenew(j[0],Movie_Award) == query[0]:
            return True
    return False

def dereferencenew(ident,database):
    for i in database.keys():
        if i != ident:
            for j in database[i][2].keys():
                if ident == j:
                    return database[i][2][j][2]
        else:
            return list(database[i][2].keys())

def findcommonapp():
    database=eval('Appearance')
    list0=[]
    for i in database.keys():
        dict1=database[i][2]
        listkey=list(dict1.keys())
        id=dict1[listkey[3]][2]
        name=dict1[listkey[2]][2]
        list0.append((id,name))  
    return list0

def findapp(actor,list):
    result=[]
    for i in list:
        if i[1]==actor:
            result.append(i[0])
    return result


def findcommonact():
    appearancelist=findcommonapp()
    print(appearancelist)
    actor=set()
    scenelist={}

    for i in appearancelist:
        actor.add(i[1])
    actor=list(actor)
    actor.sort()
    
    for i in actor:
        scenelist[i]=set(findapp(i,appearancelist))
    print(scenelist)
    result=[]
    for i in actor:
        actors=copy.deepcopy(actor)
        actors.remove(i)
        for j in actors:
            if scenelist[i].intersection(scenelist[j])==set():
                result.append((i,j))
    return result

    
def findcommonperson():
    result=findcommonact()
    ENV.push(namelist)
    keyname=[]
    listkey=[]
    database=Role
    for j in Role.keys():
        listkey.append(dereferencenew(j,database))
    for i in result:
        main=i[0]
        admirer=i[1]
        for k in listkey:
            if main==dereferencenew(k[3],database):
                main=dereferencenew(k[0],database)
            if admirer==dereferencenew(k[3],database):
                admirer=dereferencenew(k[0],database)
        keyname.append((main,admirer))
    for key in keyname:
        if (key[1],key[0]) in keyname:
            keyname.remove((key[1],key[0]))
    RES.push(keyname)

def gotfinalactor():
    keyname=RES.pop()
    database=Person
    personlist=[]
    finalresult=[]
    for i in database.keys():
        personlist.append(dereferencenew(i,database))
    for i in keyname:
        main=i[0]
        admirer=i[1]
        for k in personlist:
            if main==dereferencenew(k[0],database):
                main=dereferencenew(k[1],database)+' '+dereferencenew(k[2],database)
            if admirer==dereferencenew(k[0],database):
                admirer=dereferencenew(k[1],database)+' '+dereferencenew(k[2],database)
        finalresult.append((main,admirer))
    RES.push(finalresult)


#Query in exercise4  

def evalnew(query):
    if len(query) == 3:
        evalnew(query[0])
        evalnew(query[2])

        if query[1] == 'where':
            comp1=RES.pop()

            comp2=RES.pop()

            result=[]
            for i in comp2:
                for j in comp1:
                    if j in dereference(i):
                        result.append(i)
            RES.push(result)
            print('selection result',result)
            return

        if query[1] == 'satisfy':
            res1=RES.pop()
            ENV.pop()
            print('satisfy result')
            print(res1)

        if query[1] == 'contains':
            res1=RES.pop()
            print('contains result')
            print(res1)


        if query[1] == '=':
            comp1=distinct(ENV.pop())
            comp2=distinct(ENV.pop())
            comp3=list(comp1.intersection(comp2))
            RES.push(comp3)
            return

        if query[1] == '.':
            result=[]
            comp1=ENV.pop()
            print(comp1)
            comp2=RES.pop()
            print(comp2)
            for i in comp1:
                for j in comp2:
                    if i in dereference(j):
                        result.append(i)
            RES.push(result)
            print('Q.A attribution',result)
            return

        if query[1] == 'eq':
            comp0=[]
            comp1=RES.pop()
            comp2=RES.pop()
            for i in comp1:
                for j in comp2:
                    if dereference(i) == dereference(j):
                        comp0.append([i,j])
            RES.push(comp0)
            print('eq result',comp0)
            return

        if query[1] == 'EQJ':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            for i in comp1:
                for j in comp2:
                    i=set(i)
                    j=set(j)
                    if j.intersection(i)== i:
                        res.append(list(j))
            RES.push(res)
            print('EQJOIN',res)
            return
          
        if query[1] == 'x':
            res1=[]
            res2=[]
            res =[]
            comp1=RES.pop()
            comp2=RES.pop()
            for i in comp1:
                res1.append(dereference(i))
            for j in comp2:
                res2.append(dereference(j))
            for a in res1:
                for b in res2:
                    res.append(a+b)
            RES.push(res)
            print('Cartesian',res)
            return

            
        if query[1] == '+':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]+comp1[0])
            RES.push(res)
            print('+',res)
            return

        if query[1] == '-':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]-comp1[0])
            RES.push(res)
            print('-',res)
            return

        if query[1] == '/':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]/comp1[0])
            RES.push(res)
            print('/',res)
            return

        if query[1] == '*':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]*comp1[0])
            RES.push(res)
            print('*',res)   
        
        if query[1] == '>':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]>comp1[0])
            RES.push(res)
            print('>',res) 

        if query[1] == '<':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]<comp1[0])
            RES.push(res)
            print('<',res)  
        
        if query[1] == '==':
            res=[]
            comp1=RES.pop()
            comp2=RES.pop()
            res.append(comp2[0]==comp1[0])
            RES.push(res)
            print('==',res)  

        if query[1] == 'in':
            b = RES.pop()
            a = ENV.pop()
            res = In(a,b)
            print('in This statement is:',res)
            RES.push(res)

        if query[1] == 'contained in':
            b = ENV.pop()
            a = ENV.pop()
            res = Contains(a,b)
            print('contains This statement is:',res)
            RES.push(res)         

    
    if len(query) == 2:
        evalnew(query[1])#For next level, recursively call eval
        if query[0] == 'Count':#For the operator is 'Count()'
            comp1=RES.pop()
            length = [len(comp1)]
            RES.push(length)
            print(length)
        if query[0] == 'Sum':#For the operator is 'Sum'
            comp1=RES.pop()
            comp1=dereference(dereference(comp1[0])[0])
            for i in comp1:
                a += i
            RES.push([a])
            print('Sum',a)
        if query[0] == 'Average':#For the operator is 'Average'
            comp1=RES.pop()
            comp1=dereference(dereference(comp1[0])[0])
            for i in comp1:
                a += i
            a = a / len(comp1)
            RES.push([a])
            print('Average',a)
        if query[0] == 'Min':#For the operator is 'Min'
            comp1=RES.pop()
            comp1=dereference(dereference(comp1[0])[0])
            a = comp1[0]
            for i in comp1:
                if i < a:
                    a = i
            RES.push([a])  
            print('Min',a)              
        if query[0] == 'Max':#For the operator is 'Max'
            comp1=RES.pop()
            comp1=dereference(dereference(comp1[0])[0])
            a = comp1[0]
            for i in comp1:
                if i > a:
                    a = i
            RES.push([a])
            print('Max',a)

        if query[0] == 'exist':
            a = RES.pop()
            res = Exist(a)
            print("exist This statement is:",res)
            RES.push(res)
            

    if len(query) == 1:
        if testmoviename(query):
            findcommonperson()
            return
        if testsceneame(query):
            gotfinalactor()
            return 
        
        if creategraphcheck(query):
            RES.push(giveassociate(resultgraph))
            return

        if testassociate(query):
            actorname=RES.pop()
            RES.push(findassociate(resultgraph,actorname))
            return

        if testadmirer(query):
            getadmirer(resultgraph,RES.pop())
            return


        if nametestbigtitle(query):
            return
        
        if nametestsmalltitle(query):
            return 

        if valuetest(query):
            return

# %%
#test
print('test exercise4')
ENV=Stack(size=1000)          #load identifier
RES=Stack(size=1000)          #load element
resultgraph=Graph()

#Create identifiers list for ENV stack.
namelist=[]
for i in range(1,41):
    namelist.append(i)

q1=(('Traffic',),'contains',('associate',))
q2=(('Traffic',),'contains',('admirer',))

print('test q1, associate')
beg=time.time()
evalnew(q1)
end=time.time()
print('time cost',end-beg)
print(' ')
print('test q2, admirer')
beg=time.time()
evalnew(q2)
end=time.time()
print('time cost',end-beg)
# Out:
# test exercise4
# test q1, associate
# contains result
# ...
